# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
def sep( n: int = 140, sep: str = "="):
    print(sep*n)

def new_section(string: str, n: int = 140, sep: str = "="):
    m = len(string)
    if n < m:
        n = m + 6
    padding = (n-m+1)//2
    print(sep*padding + " " + string + " " + sep*padding)

# %%
coffee_quality = pd.read_csv("Dataset/arabica_data_cleaned_other.csv")

# %%
new_section("Coffee Arábica Quality Data")
coffee_quality["Moisture"] = coffee_quality["Moisture"]*100
print(coffee_quality.head())
sep()
# Out:
# ========================================================= Coffee Arábica Quality Data =========================================================
#    Species Variety Processing.Method  Total.Cup.Points  Moisture
# 0  Arabica   Other      Washed / Wet             89.92      12.0
# 1  Arabica   Other      Washed / Wet             88.83      12.0
# 2  Arabica   Other      Washed / Wet             88.75      11.0
# 3  Arabica   Other     Natural / Dry             88.25      10.0
# 4  Arabica   Other      Washed / Wet             87.92       0.0
# ============================================================================================================================================

# %%
new_section("Coffee Quality Arábica Data Columns")
print("Número de colunas: ", coffee_quality.shape[0])
print("Número de linhas: ", coffee_quality.shape[1])
print(coffee_quality.columns)
sep()
# Out:
# ===================================================== Coffee Quality Arábica Data Columns =====================================================
# Número de colunas:  1086
# Número de linhas:  5
# Index(['Species', 'Variety', 'Processing.Method', 'Total.Cup.Points',
#        'Moisture'],
#       dtype='object')
# ============================================================================================================================================

# %%
new_section("Coffee Quality  Arábica Data Total.Cup.Points and Description",0)
balance_stats = coffee_quality["Total.Cup.Points"].describe()
# Salvar o valor mínimo, os três quartis e o valor máximo
min_val = balance_stats["min"]
q1 = balance_stats["25%"]
median = balance_stats["50%"]
q3 = balance_stats["75%"]
max_val = balance_stats["max"]
print(balance_stats)
sep()
# Out:
# === Coffee Quality  Arábica Data Total.Cup.Points and Description ===
# count    1086.000000
# mean       82.064254
# std         2.634097
# min        59.830000
# 25%        81.080000
# 50%        82.420000
# 75%        83.500000
# max        89.920000
# Name: Total.Cup.Points, dtype: float64
# ============================================================================================================================================

# %%
# Histograma de Total.Cup.Points
plt.figure(figsize=(10, 6))
sns.histplot(coffee_quality["Total.Cup.Points"], bins=60, kde=True)
plt.title("Distribuição de Total.Cup.Points (Arábica)")
plt.show()

# Boxplots para Total.Cup.Points por Species
plt.figure(figsize=(12, 8))
sns.boxplot(x="Species", y="Total.Cup.Points", data=coffee_quality)
plt.title("Total.Cup.Points por Species (Arábica)")
plt.show()

# %%
new_section("Gráfico de Densidade do Total.Cup.Points (Arábica)")
plt.figure(figsize=(12, 8))  
sns.kdeplot(coffee_quality["Total.Cup.Points"], shade=True)  
plt.xlabel("Total.Cup.Points") 
plt.ylabel("Densidade") 
plt.title("Gráfico de Densidade do Total.Cup.Points (Arábica)")  
plt.show()
sep()
# Out:
# ============================================= Gráfico de Densidade do Total.Cup.Points (Arábica) =============================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2740075057.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(coffee_quality["Total.Cup.Points"], shade=True)
# ============================================================================================================================================

# %%
new_section("Gráfico de Densidade do Total.Cup.Points por Variety (Arábica)")
plt.figure(figsize=(12, 8))
for variety in coffee_quality["Variety"].unique():
    subset = coffee_quality[coffee_quality["Variety"] == variety]
    sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
plt.xlabel("Total.Cup.Points")
plt.ylabel("Densidade")
plt.title("KDE Plot para Total.Cup.Points por Variety (Arábica)")
plt.legend(title="Variety")
plt.show()
sep()
# Out:
# ======================================= Gráfico de Densidade do Total.Cup.Points por Variety (Arábica) =======================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\191413482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\191413482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\191413482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\191413482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\191413482.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=variety, shade=True)
# ============================================================================================================================================

# %%
new_section("Gráfico de Densidade do Total.Cup.Points por Variety")
variety_list = coffee_quality["Variety"].unique()
num_varieties = len(variety_list)

# Definir o número de colunas para os subplots
num_cols = 3
num_rows = (num_varieties + num_cols - 1) // num_cols  # Calcula o número de linhas necessário

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5 * num_rows))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, variety in enumerate(variety_list):
    subset = coffee_quality[coffee_quality["Variety"] == variety]
    sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
    axes[i].set_title(f"(Arábica) Variety: {variety}")
    axes[i].set_xlabel("Total.Cup.Points")
    axes[i].set_ylabel("Densidade")
    n = len(subset)
    axes[i].annotate(f'n={n}', xy=(0.5, 0.9), xycoords='axes fraction', ha='center', fontsize=12)

# Remover eixos extras
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
sep()
# Out:
# ============================================ Gráfico de Densidade do Total.Cup.Points por Variety ============================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3411995780.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3411995780.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3411995780.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3411995780.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3411995780.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# ============================================================================================================================================

# %%
# Calcular a frequência de cada variedade
variety_counts = coffee_quality["Variety"].value_counts()
new_section("Gráfico de Barras para Mostrar a Frequência de Cada Variedade")
# Criar um gráfico de barras para mostrar a frequência de cada variedade
plt.figure(figsize=(12, 6))
sns.barplot(x=variety_counts.index, y=variety_counts.values, palette="crest")
for index, value in enumerate(variety_counts.values):
    plt.text(index, value + 0.5, str(value), ha='center')
plt.title("Frequência de Cada Variedade de Café (Arábica)")
plt.xlabel("Variedade")
plt.ylabel("Frequência")
plt.xticks(rotation=45, ha="right")
plt.show()
sep()
# Out:
# ======================================== Gráfico de Barras para Mostrar a Frequência de Cada Variedade ========================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3089568041.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=variety_counts.index, y=variety_counts.values, palette="crest")
# ============================================================================================================================================

# %%
new_section("Gráfico de Densidade do Total.Cup.Points por Processing.Method ")
plt.figure(figsize=(12, 8))
for Processing_Method in coffee_quality["Processing.Method"].unique():
    subset = coffee_quality[coffee_quality["Processing.Method"] == Processing_Method]
    sns.kdeplot(subset["Total.Cup.Points"], label=Processing_Method, shade=True)
plt.xlabel("Total.Cup.Points")
plt.ylabel("Densidade")
plt.title("KDE Plot para Total.Cup.Points por Processing.Method")
plt.legend(title="Processing_Method")
plt.show()
sep()
# Out:
# ======================================= Gráfico de Densidade do Total.Cup.Points por Processing.Method  =======================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\618553973.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=Processing_Method, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\618553973.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=Processing_Method, shade=True)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\618553973.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], label=Processing_Method, shade=True)
# ============================================================================================================================================

# %%
new_section("Gráfico de Densidade do Total.Cup.Points por Processing.Method (Arábica)")
method_list = coffee_quality["Processing.Method"].unique()
num_methods = len(method_list)

# Definir o número de colunas para os subplots
num_cols = 3
num_rows = (num_methods + num_cols - 1) // num_cols  # Calcula o número de linhas necessário

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5 * num_rows))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, method in enumerate(method_list):
    subset = coffee_quality[coffee_quality["Processing.Method"] == method]
    sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
    axes[i].set_title(f"(Arábica) Processing Method: {method}")
    axes[i].set_xlabel("Total.Cup.Points")
    axes[i].set_ylabel("Densidade")
    n = len(subset)
    axes[i].annotate(f'instâncias={n}', xy=(0.5, 0.9), xycoords='axes fraction', ha='center', fontsize=12, color='black')

# Remover eixos extras
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
sep()
# Out:
# ================================== Gráfico de Densidade do Total.Cup.Points por Processing.Method (Arábica) ==================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\4230546860.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\4230546860.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\4230546860.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset["Total.Cup.Points"], shade=True, ax=axes[i])
# ============================================================================================================================================

# %%
# Calcular a frequência de cada variedade
Processing_Method_counts = coffee_quality["Processing.Method"].value_counts()
# Criar um gráfico de barras para mostrar a frequência de cada variedade
plt.figure(figsize=(12, 6))
sns.barplot(x=Processing_Method_counts.index, y=Processing_Method_counts.values, palette="crest")
for index, value in enumerate(Processing_Method_counts.values):
    plt.text(index, value + 0.5, str(value), ha='center')
plt.title("Frequência de Cada Processing_Method de Café (Arábica)")
plt.xlabel("Processing_Method")
plt.ylabel("Frequência")
plt.xticks(rotation=10, ha="right")
plt.show()
# Out:
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\3009106783.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Processing_Method_counts.index, y=Processing_Method_counts.values, palette="crest")

# %%
new_section("Coffee Quality Data Moisture and Description (Arábica)")
correlation = coffee_quality[["Total.Cup.Points", "Moisture"]].corr()
print(correlation)

# Heatmap de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(coffee_quality[["Total.Cup.Points", "Moisture"]].corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap de Correlação (Arábica)")
plt.show()
sep()
# Out:
# =========================================== Coffee Quality Data Moisture and Description (Arábica) ===========================================
#                   Total.Cup.Points  Moisture
# Total.Cup.Points          1.000000 -0.146449
# Moisture                 -0.146449  1.000000
# ============================================================================================================================================

# %%
new_section("Boxplot de Moisture (Arábica)")
# Criar um boxplot para Moisture
plt.figure(figsize=(10, 6))
sns.boxplot(x=coffee_quality["Moisture"])
plt.title("Boxplot de Moisture (Arábica)")
plt.xlabel("Moisture")
plt.show()
sep()
# Out:
# ======================================================== Boxplot de Moisture (Arábica) ========================================================
# ============================================================================================================================================

# %%
min_val = balance_stats["min"]
q1 = balance_stats["25%"]
median = balance_stats["50%"]
q3 = balance_stats["75%"]
max_val = balance_stats["max"]

# %%
new_section("Gráfico de Densidade para Moisture (Arábica)")
# Definir faixas de Total.Cup.Points
coffee_quality["Total.Cup.Points.Range"] = pd.cut(coffee_quality["Total.Cup.Points"], bins=[min_val, q1, median, q3, max_val], labels=["min_val-q1", "q1-median", "median-q3", "q3-max_val"])

# Função personalizada para adicionar anotações em gráficos de densidade
def annotated_kdeplot(data, **kwargs):
    ax = sns.kdeplot(data, **kwargs)
    n = len(data)
    ax.annotate(f'n={n}', xy=(0.5, 0.95), xycoords='axes fraction', ha='center', fontsize=12, color='black')

# Criar um FacetGrid para gráficos de densidade com anotações
g = sns.FacetGrid(coffee_quality, col="Total.Cup.Points.Range", col_wrap=4, height=4, aspect=1.5)
g.map_dataframe(annotated_kdeplot, x="Moisture", shade=True)

# Ajustar os títulos e labels
g.set_axis_labels("Moisture", "Densidade")
g.set_titles(col_template="(Arábica) Total.Cup.Points: {col_name}")

plt.show()
sep()
# Out:
# ================================================ Gráfico de Densidade para Moisture (Arábica) ================================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2061786225.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data, **kwargs)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2061786225.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data, **kwargs)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2061786225.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data, **kwargs)
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2061786225.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data, **kwargs)
# ============================================================================================================================================

# %%
new_section("Gráfico de Densidade para Moisture (Arábica)")
plt.figure(figsize=(12, 8))
sns.kdeplot(coffee_quality["Moisture"], shade=True)
plt.xlabel("Moisture")
plt.ylabel("Densidade")
plt.title("KDE Plot para Moisture (Arábica)")
plt.show()
sep()
# Out:
# ================================================ Gráfico de Densidade para Moisture (Arábica) ================================================
# C:\Users\Isas_\AppData\Local\Temp\ipykernel_18028\2644542595.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(coffee_quality["Moisture"], shade=True)
# ============================================================================================================================================
